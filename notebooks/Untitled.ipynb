# %%
# %load /Users/hwayment/ipynb_defaults.py
# %load_ext autoreload
# %autoreload 2

# %pylab inline
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style('white')
sns.set_context('poster')

from matplotlib.colors import LogNorm

from glob import glob
import os, sys, pickle, requests
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('..')
from utils.energy_utils import Parameters, Motif
from conformation import Conformation
from design import Design
from plot import *

# %%
tmp = Design(secstruct='..[[[. ]]]', pattern='NNCGCNGCG', params=Parameters(gnm=False))
tmp.run()
# Out:
# Found 64 sequences to test

# %%
best_conf = Conformation(sequence=tmp.sequences[0],params=Parameters(gnm=False))
best_conf.run()
worst_conf = Conformation(sequence=tmp.sequences[-1],params=Parameters(gnm=False))
worst_conf.run()
figure(figsize=(8,4))
subplot(1,2,1)
draw_traces(best_conf,n_confs=10)
subplot(1,2,2)
draw_traces(worst_conf,n_confs=10)

# %%
# minimal FMN MS2 switch

fmn_motif = Motif('(x(&)x)' ,dG=-1)
ms2_motif = Motif('((x))' ,dG=-1)

fmn_motif = Motif('(.(&).)' ,dG=-1)

# %%
tmp = Design(secstruct='...(.)', params=Parameters(gnm=False))
tmp.run()
# Out:
# Found 256 sequences to test

# %%
conf = Conformation(secstruct='_(.)_')
conf.run()
draw_conformations(conf, structs_per_row = 7)
# Out:
# Scoring includes GNM elastic energy
# ../utils/energy_utils.py:170: RuntimeWarning: invalid value encountered in log

# %%
# Out:
# 'NNNNN'

# %%
conf = Conformation(secstruct='.(.).',params=Parameters(gnm=False))
conf.run()
draw_conformations(conf, structs_per_row = 7)

# %%
conf = Conformation(secstruct='((.))',params=Parameters(gnm=False))
conf.run()
draw_conformations(conf, structs_per_row = 7)
