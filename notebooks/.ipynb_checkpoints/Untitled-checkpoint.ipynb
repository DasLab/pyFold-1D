# %%
# %load /Users/hwayment/ipynb_defaults.py
# %load_ext autoreload
# %autoreload 2

# %pylab inline
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style('white')
sns.set_context('poster')

from matplotlib.colors import LogNorm

from glob import glob
import os, sys, pickle, requests
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('..')
from utils.energy_utils import Parameters, Motif
from conformation import Conformation
from design import Design

# %%
def score_ratio_(z1, z2):
    return z1/z2

tmp = Design(secstruct=['((.))','.....'], n_switch_states=2, score_function = (lambda z1, z2: z1/z2),
             params=[Parameters(gnm=False)]*2)
tmp.run()
# Out:
# Found 16 sequences to test

# %%
tmp = Design(secstruct='...(.)', params=Parameters(gnm=False))
tmp.run()
# Out:
# Found 256 sequences to test

# %%
# Out:
# {1, 2, 3, 4}
